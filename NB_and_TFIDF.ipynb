# %%
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
import multiprocessing
import nltk
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
import pymorphy3
import re

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score
from sklearn.preprocessing import OrdinalEncoder

from xgboost import XGBClassifier

multiprocessing.cpu_count()
# Out:
# 16

# %%
df = pd.read_json("kinopoisk.jsonl", lines=True, convert_dates = ['date'])

df.head()
# Out:
#      part   movie_name  review_id         author       date  \
# 0  top250  Блеф (1976)      17144      Come Back 2011-09-24
# 1  top250  Блеф (1976)      17139        Stasiki 2008-03-04
# 2  top250  Блеф (1976)      17137       Flashman 2007-03-04
# 3  top250  Блеф (1976)      17135  Sergio Tishin 2009-08-17
# 4  top250  Блеф (1976)      17151        Фюльгья 2009-08-20
#
#                                                title   grade3  grade10  \
# 0                             Плакали наши денежки ©     Good     10.0
# 1                                               None     Good      0.0
# 2                                               None     Good     10.0
# 3  " Черное, красное, ерунда это все. Выигрывает ...     Good      0.0
# 4                «Он хотел убежать? Да! Блеф, блеф…»  Neutral      7.0
#
#                                              content
# 0  \n"Блеф» — одна из моих самых любимых комедий....
# 1  \nАдриано Челентано продолжает радовать нас св...
# 2  \nНесомненно, это один из великих фильмов 80-х...
# 3  \nЭта фраза на мой взгляд отражает сюжет несом...
# 4  \n- как пела Земфира, скорее всего, по соверше...

# %%
import re

df['content'] = df['content'].apply(lambda st: re.sub('\n', ' ', st))
df['content'] = df['content'].apply(lambda st: re.sub('\xa0', ' ', st))
df['content'] = df['content'].apply(lambda st: re.sub('\nA', ' ', st))

#re.sub('\xa0', '', st)

# %% [markdown]
# ## Обработка текста

# %%
# Создаём копию датасета для BoW

df_bow = df[['content', 'grade3', 'grade10']].copy()

df_bow.head()


# Убираем знаки препинания
df_bow['content'] = df_bow['content'].apply(lambda text: re.sub(r'[^\w\s]', '', text))
df_bow
# Out:
#                                                  content   grade3  grade10
# 0       Блеф  одна из моих самых любимых комедий  Это...     Good     10.0
# 1       Адриано Челентано продолжает радовать нас сво...     Good      0.0
# 2       Несомненно это один из великих фильмов 80х го...     Good     10.0
# 3       Эта фраза на мой взгляд отражает сюжет несомн...     Good      0.0
# 4        как пела Земфира скорее всего по совершенно ...  Neutral      7.0
# ...                                                  ...      ...      ...
# 36586         Ну с чего бы начать Давненько я не писа...      Bad      2.0
# 36587         Можно начать с того что уже постер к фи...      Bad      1.0
# 36588         Фильм производства России поэтому многи...     Good      7.0
# 36589         16 сентября на большие экраны вышел мис...      Bad      0.0
# 36590         Эх как я пыталась настроить себя положи...      Bad      1.0
#
# [36591 rows x 3 columns]

# %%
# Как поступить с заголовками?
# 1) Отбросить
# 2) Добавить к основному тексту отзыва
# 3) Сравнить перфомансы
tokenizer = nltk.tokenize.WordPunctTokenizer()

def lower_join_tokenizer(st):
  st=str(st)
  return ' '.join(tokenizer.tokenize(st.lower()))

df_bow['content'] = df_bow['content'].apply(lower_join_tokenizer)


#df_bow.to_csv('bow_kinopoisk.csv')

# %%
df_bow
# Out:
#                                                  content   grade3  grade10
# 0      блеф одна из моих самых любимых комедий этот ф...     Good     10.0
# 1      адриано челентано продолжает радовать нас свои...     Good      0.0
# 2      несомненно это один из великих фильмов 80х год...     Good     10.0
# 3      эта фраза на мой взгляд отражает сюжет несомне...     Good      0.0
# 4      как пела земфира скорее всего по совершенно др...  Neutral      7.0
# ...                                                  ...      ...      ...
# 36586  ну с чего бы начать давненько я не писала отри...      Bad      2.0
# 36587  можно начать с того что уже постер к фильму цв...      Bad      1.0
# 36588  фильм производства россии поэтому многие ожида...     Good      7.0
# 36589  16 сентября на большие экраны вышел мистически...      Bad      0.0
# 36590  эх как я пыталась настроить себя положительно ...      Bad      1.0
#
# [36591 rows x 3 columns]

# %%
def lemmatize(st):
    morph_analyzer = pymorphy3.MorphAnalyzer()
    return [morph_analyzer.parse(word)[0].normal_form for word in st.split()]

# %%
# !pip install pymorphy3
# Out:
# Requirement already satisfied: pymorphy3 in c:\users\user\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from pymorphy3) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\user\anaconda3\lib\site-packages (from pymorphy3) (2.4.417150.4580142)
# Requirement already satisfied: setuptools>=68.2.2 in c:\users\user\anaconda3\lib\site-packages (from pymorphy3) (69.5.1)

# %%
# %%time
result = Parallel(n_jobs=8, verbose=10)(delayed(lemmatize)(text) for text in df_bow['content'])
df_bow['clean_content'] = result
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.19772261127393442s.) Setting batch_size=2.
# [Parallel(n_jobs=8)]: Done  45 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  82 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 108 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 138 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 168 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 202 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 236 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 274 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 312 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 354 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 396 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 442 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 488 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 538 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 588 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 642 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=8)]: Done 696 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=8)]: Done 754 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=8)]: Done 812 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=8)]: Done 874 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=8)]: Done 936 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=8)]: Done 1002 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=8)]: Done 1068 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=8)]: Done 1138 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=8)]: Done 1208 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=8)]: Done 1282 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=8)]: Done 1356 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=8)]: Done 1434 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=8)]: Done 1512 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=8)]: Done 1594 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=8)]: Done 1676 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=8)]: Done 1762 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=8)]: Done 1848 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=8)]: Done 1938 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=8)]: Done 2028 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=8)]: Done 2122 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=8)]: Done 2216 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=8)]: Done 2314 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=8)]: Done 2412 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=8)]: Done 2514 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=8)]: Done 2616 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=8)]: Done 2722 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=8)]: Done 2828 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=8)]: Done 2938 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=8)]: Done 3048 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=8)]: Done 3162 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=8)]: Done 3276 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=8)]: Done 3394 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=8)]: Done 3512 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 3634 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 3756 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 3882 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 4008 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 4138 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 4268 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 4402 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 4536 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 4674 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 4812 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 4954 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 5096 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 5242 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 5388 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=8)]: Done 5538 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=8)]: Done 5688 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 5842 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 5996 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=8)]: Done 6154 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=8)]: Done 6312 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 6474 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 6636 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 6802 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 6968 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=8)]: Done 7138 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=8)]: Done 7308 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=8)]: Done 7482 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=8)]: Done 7656 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=8)]: Done 7834 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=8)]: Done 8012 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 8194 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 8376 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 8562 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 8748 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 8938 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=8)]: Done 9128 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=8)]: Done 9322 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=8)]: Done 9516 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=8)]: Done 9714 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=8)]: Done 9912 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=8)]: Done 10114 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=8)]: Done 10316 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=8)]: Done 10522 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=8)]: Done 10728 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=8)]: Done 10938 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=8)]: Done 11148 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=8)]: Done 11362 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=8)]: Done 11576 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=8)]: Done 11794 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=8)]: Done 12012 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=8)]: Done 12234 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=8)]: Done 12456 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=8)]: Done 12682 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=8)]: Done 12908 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=8)]: Done 13138 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=8)]: Done 13368 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=8)]: Done 13602 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=8)]: Done 13836 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=8)]: Done 14074 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=8)]: Done 14312 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=8)]: Done 14554 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=8)]: Done 14796 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=8)]: Done 15042 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=8)]: Done 15288 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=8)]: Done 15538 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=8)]: Done 15788 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=8)]: Done 16042 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=8)]: Done 16296 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=8)]: Done 16554 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=8)]: Done 16812 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=8)]: Done 17074 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=8)]: Done 17336 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=8)]: Done 17602 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=8)]: Done 17868 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=8)]: Done 18138 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=8)]: Done 18408 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=8)]: Done 18682 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=8)]: Done 18956 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=8)]: Done 19234 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=8)]: Done 19512 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=8)]: Done 19794 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=8)]: Done 20076 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=8)]: Done 20362 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=8)]: Done 20648 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=8)]: Done 20938 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=8)]: Done 21228 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=8)]: Done 21522 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=8)]: Done 21816 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=8)]: Done 22114 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=8)]: Done 22412 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=8)]: Done 22714 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=8)]: Done 23016 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=8)]: Done 23322 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=8)]: Done 23628 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=8)]: Done 23938 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=8)]: Done 24248 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=8)]: Done 24562 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=8)]: Done 24876 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=8)]: Done 25194 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=8)]: Done 25512 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=8)]: Done 25834 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=8)]: Done 26156 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=8)]: Done 26482 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=8)]: Done 26808 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=8)]: Done 27138 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=8)]: Done 27468 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=8)]: Done 27802 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=8)]: Done 28136 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=8)]: Done 28474 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=8)]: Done 28812 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=8)]: Done 29154 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=8)]: Done 29496 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=8)]: Done 29842 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=8)]: Done 30188 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=8)]: Done 30538 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=8)]: Done 30888 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=8)]: Done 31242 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=8)]: Done 31596 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=8)]: Done 31954 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=8)]: Done 32312 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=8)]: Done 32674 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=8)]: Done 33036 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=8)]: Done 33402 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=8)]: Done 33768 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=8)]: Done 34138 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=8)]: Done 34508 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=8)]: Done 34882 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=8)]: Done 35256 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=8)]: Done 35634 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=8)]: Done 36012 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=8)]: Done 36394 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=8)]: Done 36576 out of 36591 | elapsed: 11.1min remaining:    0.2s
# CPU times: total: 3.81 s
# Wall time: 11min 5s
# [Parallel(n_jobs=8)]: Done 36591 out of 36591 | elapsed: 11.1min finished

# %%
df_bow.head()
# Out:
#                                              content   grade3  grade10
# 0  блеф одна из моих самых любимых комедий этот ф...     Good     10.0
# 1  адриано челентано продолжает радовать нас свои...     Good      0.0
# 2  несомненно это один из великих фильмов 80х год...     Good     10.0
# 3  эта фраза на мой взгляд отражает сюжет несомне...     Good      0.0
# 4  как пела земфира скорее всего по совершенно др...  Neutral      7.0

# %%
nltk.download('stopwords')
stop_list = stopwords.words('russian')



df_bow['clean_content'] = df_bow['clean_content'].apply(lambda x: [item for item in x if item not in stop_list])
df_bow.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                              content   grade3  grade10  \
# 0  блеф одна из моих самых любимых комедий этот ф...     Good     10.0
# 1  адриано челентано продолжает радовать нас свои...     Good      0.0
# 2  несомненно это один из великих фильмов 80х год...     Good     10.0
# 3  эта фраза на мой взгляд отражает сюжет несомне...     Good      0.0
# 4  как пела земфира скорее всего по совершенно др...  Neutral      7.0
#
#                                        clean_content
# 0  [блеф, самый, любимый, комедия, фильм, наверно...
# 1  [адриано, челентано, продолжать, радовать, сво...
# 2  [несомненно, это, великий, фильм, 80х, год, ис...
# 3  [фраза, взгляд, отражать, сюжет, несомненно, п...
# 4  [петь, земфира, скорее, весь, совершенно, пово...

# %%
df_bow.to_pickle('lemmed_df.pkl')

# %% [markdown]
# ## TF-IDF векторизация

# %%
df_bow = pd.read_csv('lemmed_df.csv').drop(columns = ['Unnamed: 0'])
df_bow.head()
# Out:
#                                              content   grade3  grade10  \
# 0  блеф одна из моих самых любимых комедий этот ф...     Good     10.0
# 1  адриано челентано продолжает радовать нас свои...     Good      0.0
# 2  несомненно это один из великих фильмов 80х год...     Good     10.0
# 3  эта фраза на мой взгляд отражает сюжет несомне...     Good      0.0
# 4  как пела земфира скорее всего по совершенно др...  Neutral      7.0
#
#                                        clean_content
# 0  ['блеф', 'самый', 'любимый', 'комедия', 'фильм...
# 1  ['адриано', 'челентано', 'продолжать', 'радова...
# 2  ['несомненно', 'это', 'великий', 'фильм', '80х...
# 3  ['фраза', 'взгляд', 'отражать', 'сюжет', 'несо...
# 4  ['петь', 'земфира', 'скорее', 'весь', 'соверше...

# %%
df_bow = pd.read_pickle('lemmed_df.pkl')

df_bow['clean_content'][0]
# Out:
# ['блеф',
#  'самый',
#  'любимый',
#  'комедия',
#  'фильм',
#  'наверно',
#  'смотреть',
#  'сто',
#  'блефовать',
#  'видеть',
#  'большой',
#  'мочь',
#  'выразить',
#  'свой',
#  'восхищение',
#  'главный',
#  'действовать',
#  'лицо',
#  'это',
#  'фильм',
#  'начать',
#  'адриано',
#  'челентано',
#  'который',
#  'считать',
#  'это',
#  'хороший',
#  'роль',
#  'кино',
#  'великолепный',
#  'актёр',
#  'неплохой',
#  'певец',
#  'странно',
#  'родина',
#  'италия',
#  'песня',
#  'мало',
#  'слушать',
#  'думать',
#  'итальянец',
#  'француз',
#  'привыкнуть',
#  'сей',
#  'актёр',
#  'популярный',
#  'свой',
#  'родина',
#  'парадокс',
#  'челентано',
#  'профессионал',
#  'свой',
#  'дело',
#  'комик',
#  'серьёзный',
#  'выражение',
#  'лицо',
#  'смешной',
#  'ещё',
#  'одновременно',
#  'серъёзный',
#  'адриано',
#  'браво',
#  'несколько',
#  'слово',
#  'энтони',
#  'куиня',
#  'самый',
#  'горбун',
#  'нотрдама',
#  'собор',
#  'парижский',
#  'богоматерь',
#  'оригинальный',
#  'версия',
#  'смотреть',
#  'рекомендовать',
#  'както',
#  'приключиться',
#  'интересный',
#  'история',
#  'съёмка',
#  'свой',
#  'фильм',
#  'сломать',
#  'подвихнуть',
#  'нога',
#  'роль',
#  'требовать',
#  'сцена',
#  'кружиться',
#  'дама',
#  'танец',
#  'вместе',
#  'съёмочный',
#  'коллектив',
#  'выйти',
#  'это',
#  'положение',
#  'сделать',
#  'вращаться',
#  'платформа',
#  'который',
#  'создавать',
#  'видимость',
#  'весь',
#  'ритм',
#  'танец',
#  'история',
#  'слово',
#  'это',
#  'замечательный',
#  'актёр',
#  'фильм',
#  'жанр',
#  'который',
#  'смело',
#  'обозвать',
#  'авантюра',
#  'комедийный',
#  'авантюра',
#  'некий',
#  'белля',
#  'дьюк',
#  'весьма',
#  'влиятельный',
#  'дама',
#  'пытаться',
#  'освободить',
#  'свой',
#  'старое',
#  'знакомый',
#  'авантюрист',
#  'филипп',
#  'бенга',
#  'который',
#  'давний',
#  'счёты',
#  'вместо',
#  'свобода',
#  'оказываться',
#  'комбинатораферист',
#  'имя',
#  'феликс',
#  'битый',
#  'головорез',
#  'белля',
#  'дьюк',
#  'разрабатывать',
#  'план',
#  'побег',
#  'бэнг',
#  'встречаться',
#  'череда',
#  'смешной',
#  'сцена',
#  'заставить',
#  'зритель',
#  'разразиться',
#  'шквальный',
#  'смех',
#  'умение',
#  'блефовать',
#  'просто',
#  'равный',
#  'главное',
#  'правило',
#  'блеф',
#  'сработать',
#  'поверить',
#  'помимо',
#  'весь',
#  'это',
#  'ещё',
#  'соревноваться',
#  'стратегия',
#  'блеф',
#  'некоторый',
#  'сцена',
#  'обман',
#  'запомниться',
#  'надолго',
#  'особенно',
#  'сцена',
#  'магазин',
#  'ткань',
#  'привет',
#  'старина',
#  'выпустить',
#  'лепрозорий',
#  'оттуда',
#  'сбежать',
#  'финальный',
#  'сцена',
#  'который',
#  'охарактеризовать',
#  'слово',
#  'смех',
#  'сквозь',
#  'слеза',
#  'завершение',
#  'сказать',
#  'это',
#  'великолепный',
#  'кино',
#  'смотреть',
#  'пересматривать',
#  'очень',
#  'оно',
#  'потерять',
#  'свой',
#  'шарм',
#  'обаяние',
#  '10',
#  '10']

# %%
df_bow['clean_content'] = df_bow['clean_content'].str.join(' ')

# %%
df_bow['grade3'].value_counts()
# Out:
# grade3
# Good       27264
# Bad         4751
# Neutral     4576
# Name: count, dtype: int64

# %%
count_vec = CountVectorizer()

count_vec.fit(df_bow['clean_content'])
# Out:
# CountVectorizer()

# %%
matrix = count_vec.fit_transform(df_bow['clean_content'].values)
freqs = zip(count_vec.get_feature_names_out(), matrix.sum(axis=0))    
# sort from largest to smallest
A = np.squeeze(np.asarray(matrix.sum(axis=0)))
freqs = zip(count_vec.get_feature_names_out(), A)    
sorted(freqs, key=lambda x: -x[1])[:10]
# Out:
# [('фильм', 177682),
#  ('это', 142066),
#  ('который', 83746),
#  ('всё', 77457),
#  ('свой', 64003),
#  ('весь', 55049),
#  ('человек', 50215),
#  ('очень', 41916),
#  ('10', 41407),
#  ('мочь', 38706)]

# %%
df_bow_balanced = df_bow[df_bow['grade3']=='Good'].sample(n = 4600, random_state=42)

df_bow_balanced = pd.concat([df_bow_balanced, df_bow[df_bow['grade3']!='Good']]).reset_index(drop = True)

# %%
reviews = df_bow_balanced['clean_content'].values



tfidf = TfidfVectorizer(max_features=1500)

tfidf.fit(df_bow['clean_content'].values)

X = tfidf.transform(reviews)
X.shape
# Out:
# (13927, 1500)

# %%
OE = OrdinalEncoder(categories=[['Bad', 'Neutral', 'Good']])
y = OE.fit_transform(df_bow_balanced['grade3'].values.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
params = {
        'min_child_weight': [1, 5, 10],
        'max_depth': [4, 5, 6]
        }

# %%
# %%time
XGBC = XGBClassifier(n_jobs = 4)

XGBC.fit(X_train, y_train)

predictions = XGBC.predict(X_test)

#Calculating accuracy
# Out:
# CPU times: total: 1min 27s
# Wall time: 34.2 s

# %%
from sklearn.model_selection import GridSearchCV  
from dask.distributed import Client, LocalCluster 
import joblib

# %%
folds = 3
param_comb = 5

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)

grid_search = GridSearchCV(XGBC, param_grid=params, cv = 5, scoring = 'accuracy', verbose=10)

# create a local Dask cluster
'''
cluster = LocalCluster()  

client = Client(cluster)  



with joblib.parallel_backend("dask", scatter=[X_train, y_train]):  

    grid_search.fit(X_train, y_train)

'''
# Here we go
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START max_depth=4, min_child_weight=1.............................
# [CV 1/5; 1/9] END max_depth=4, min_child_weight=1;, score=0.663 total time=  15.6s
# [CV 2/5; 1/9] START max_depth=4, min_child_weight=1.............................
# [CV 2/5; 1/9] END max_depth=4, min_child_weight=1;, score=0.652 total time=  15.1s
# [CV 3/5; 1/9] START max_depth=4, min_child_weight=1.............................
# [CV 3/5; 1/9] END max_depth=4, min_child_weight=1;, score=0.669 total time=  15.9s
# [CV 4/5; 1/9] START max_depth=4, min_child_weight=1.............................
# [CV 4/5; 1/9] END max_depth=4, min_child_weight=1;, score=0.685 total time=  14.6s
# [CV 5/5; 1/9] START max_depth=4, min_child_weight=1.............................
# [CV 5/5; 1/9] END max_depth=4, min_child_weight=1;, score=0.663 total time=  14.6s
# [CV 1/5; 2/9] START max_depth=4, min_child_weight=5.............................
# [CV 1/5; 2/9] END max_depth=4, min_child_weight=5;, score=0.667 total time=  13.3s
# [CV 2/5; 2/9] START max_depth=4, min_child_weight=5.............................
# [CV 2/5; 2/9] END max_depth=4, min_child_weight=5;, score=0.655 total time=  13.4s
# [CV 3/5; 2/9] START max_depth=4, min_child_weight=5.............................
# [CV 3/5; 2/9] END max_depth=4, min_child_weight=5;, score=0.658 total time=  13.3s
# [CV 4/5; 2/9] START max_depth=4, min_child_weight=5.............................
# [CV 4/5; 2/9] END max_depth=4, min_child_weight=5;, score=0.681 total time=  14.7s
# [CV 5/5; 2/9] START max_depth=4, min_child_weight=5.............................
# [CV 5/5; 2/9] END max_depth=4, min_child_weight=5;, score=0.664 total time=  13.2s
# [CV 1/5; 3/9] START max_depth=4, min_child_weight=10............................
# [CV 1/5; 3/9] END max_depth=4, min_child_weight=10;, score=0.669 total time=  12.5s
# [CV 2/5; 3/9] START max_depth=4, min_child_weight=10............................
# [CV 2/5; 3/9] END max_depth=4, min_child_weight=10;, score=0.655 total time=  13.0s
# [CV 3/5; 3/9] START max_depth=4, min_child_weight=10............................
# [CV 3/5; 3/9] END max_depth=4, min_child_weight=10;, score=0.676 total time=  13.2s
# [CV 4/5; 3/9] START max_depth=4, min_child_weight=10............................
# [CV 4/5; 3/9] END max_depth=4, min_child_weight=10;, score=0.692 total time=  13.1s
# [CV 5/5; 3/9] START max_depth=4, min_child_weight=10............................
# [CV 5/5; 3/9] END max_depth=4, min_child_weight=10;, score=0.667 total time=  12.6s
# [CV 1/5; 4/9] START max_depth=5, min_child_weight=1.............................
# [CV 1/5; 4/9] END max_depth=5, min_child_weight=1;, score=0.663 total time=  21.3s
# [CV 2/5; 4/9] START max_depth=5, min_child_weight=1.............................
# [CV 2/5; 4/9] END max_depth=5, min_child_weight=1;, score=0.657 total time=  21.7s
# [CV 3/5; 4/9] START max_depth=5, min_child_weight=1.............................
# [CV 3/5; 4/9] END max_depth=5, min_child_weight=1;, score=0.667 total time=  22.6s
# [CV 4/5; 4/9] START max_depth=5, min_child_weight=1.............................
# [CV 4/5; 4/9] END max_depth=5, min_child_weight=1;, score=0.676 total time=  23.5s
# [CV 5/5; 4/9] START max_depth=5, min_child_weight=1.............................
# [CV 5/5; 4/9] END max_depth=5, min_child_weight=1;, score=0.660 total time=  21.2s
# [CV 1/5; 5/9] START max_depth=5, min_child_weight=5.............................
# [CV 1/5; 5/9] END max_depth=5, min_child_weight=5;, score=0.668 total time=  17.4s
# [CV 2/5; 5/9] START max_depth=5, min_child_weight=5.............................
# [CV 2/5; 5/9] END max_depth=5, min_child_weight=5;, score=0.660 total time=  17.5s
# [CV 3/5; 5/9] START max_depth=5, min_child_weight=5.............................
# [CV 3/5; 5/9] END max_depth=5, min_child_weight=5;, score=0.659 total time=  17.8s
# [CV 4/5; 5/9] START max_depth=5, min_child_weight=5.............................
# [CV 4/5; 5/9] END max_depth=5, min_child_weight=5;, score=0.676 total time=  17.7s
# [CV 5/5; 5/9] START max_depth=5, min_child_weight=5.............................
# [CV 5/5; 5/9] END max_depth=5, min_child_weight=5;, score=0.669 total time=  17.8s
# [CV 1/5; 6/9] START max_depth=5, min_child_weight=10............................
# [CV 1/5; 6/9] END max_depth=5, min_child_weight=10;, score=0.663 total time=  15.9s
# [CV 2/5; 6/9] START max_depth=5, min_child_weight=10............................
# [CV 2/5; 6/9] END max_depth=5, min_child_weight=10;, score=0.660 total time=  15.9s
# [CV 3/5; 6/9] START max_depth=5, min_child_weight=10............................
# [CV 3/5; 6/9] END max_depth=5, min_child_weight=10;, score=0.662 total time=  16.0s
# [CV 4/5; 6/9] START max_depth=5, min_child_weight=10............................
# [CV 4/5; 6/9] END max_depth=5, min_child_weight=10;, score=0.683 total time=  15.8s
# [CV 5/5; 6/9] START max_depth=5, min_child_weight=10............................
# [CV 5/5; 6/9] END max_depth=5, min_child_weight=10;, score=0.661 total time=  16.3s
# [CV 1/5; 7/9] START max_depth=6, min_child_weight=1.............................
# [CV 1/5; 7/9] END max_depth=6, min_child_weight=1;, score=0.668 total time=  28.9s
# [CV 2/5; 7/9] START max_depth=6, min_child_weight=1.............................
# [CV 2/5; 7/9] END max_depth=6, min_child_weight=1;, score=0.655 total time=  28.4s
# [CV 3/5; 7/9] START max_depth=6, min_child_weight=1.............................
# [CV 3/5; 7/9] END max_depth=6, min_child_weight=1;, score=0.666 total time=  30.2s
# [CV 4/5; 7/9] START max_depth=6, min_child_weight=1.............................
# [CV 4/5; 7/9] END max_depth=6, min_child_weight=1;, score=0.678 total time=  29.3s
# [CV 5/5; 7/9] START max_depth=6, min_child_weight=1.............................
# [CV 5/5; 7/9] END max_depth=6, min_child_weight=1;, score=0.655 total time=  29.2s
# [CV 1/5; 8/9] START max_depth=6, min_child_weight=5.............................
# [CV 1/5; 8/9] END max_depth=6, min_child_weight=5;, score=0.666 total time=  24.6s
# [CV 2/5; 8/9] START max_depth=6, min_child_weight=5.............................
# [CV 2/5; 8/9] END max_depth=6, min_child_weight=5;, score=0.658 total time=  23.9s
# [CV 3/5; 8/9] START max_depth=6, min_child_weight=5.............................
# [CV 3/5; 8/9] END max_depth=6, min_child_weight=5;, score=0.663 total time=  24.2s
# [CV 4/5; 8/9] START max_depth=6, min_child_weight=5.............................
# [CV 4/5; 8/9] END max_depth=6, min_child_weight=5;, score=0.685 total time=  22.8s
# [CV 5/5; 8/9] START max_depth=6, min_child_weight=5.............................
# [CV 5/5; 8/9] END max_depth=6, min_child_weight=5;, score=0.667 total time=  22.5s
# [CV 1/5; 9/9] START max_depth=6, min_child_weight=10............................
# [CV 1/5; 9/9] END max_depth=6, min_child_weight=10;, score=0.662 total time=  21.5s
# [CV 2/5; 9/9] START max_depth=6, min_child_weight=10............................
# [CV 2/5; 9/9] END max_depth=6, min_child_weight=10;, score=0.666 total time=  20.1s
# [CV 3/5; 9/9] START max_depth=6, min_child_weight=10............................
# [CV 3/5; 9/9] END max_depth=6, min_child_weight=10;, score=0.668 total time=  20.9s
# [CV 4/5; 9/9] START max_depth=6, min_child_weight=10............................
# [CV 4/5; 9/9] END max_depth=6, min_child_weight=10;, score=0.682 total time=  21.7s
# [CV 5/5; 9/9] START max_depth=6, min_child_weight=10............................
# [CV 5/5; 9/9] END max_depth=6, min_child_weight=10;, score=0.658 total time=  22.0s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=4, num_parallel_tree=None,
#                                      objective='multi:softprob', ...),
#              param_grid={'max_depth': [4, 5, 6],
#                          'min_child_weight': [1, 5, 10]},
#              scoring='accuracy', verbose=10)

# %%
random_search.best_score_
# Out:
# nan

# %%
accuracy = accuracy_score(y_test, predictions)
accuracy
# Out:
# 0.6734635267087881

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.73      0.72      1183
#          1.0       0.55      0.57      0.56      1143
#          2.0       0.77      0.72      0.74      1156
#
#     accuracy                           0.67      3482
#    macro avg       0.68      0.67      0.67      3482
# weighted avg       0.68      0.67      0.67      3482

# %%
feature_array = np.array(tfidf.get_feature_names_out())
tfidf_sorting = np.argsort(X.toarray()).flatten()[::-1]

n = 3
top_n = feature_array[tfidf_sorting][:n]

# %%
top_n
# Out:
# array(['сон', 'подруга', 'крутой'], dtype=object)

# %%
# Out:
# CountVectorizer()

# %%
# Out:
# [('00', matrix([[  7, 346,   1, ...,   1,   1,   1]], dtype=int64))]

# %%
# Out:
# [('фильм', 177682),
#  ('это', 142066),
#  ('который', 83746),
#  ('всё', 77457),
#  ('свой', 64003),
#  ('весь', 55049),
#  ('человек', 50215),
#  ('очень', 41916),
#  ('10', 41407),
#  ('мочь', 38706),
#  ('хороший', 38411),
#  ('просто', 33923),
#  ('жизнь', 33892),
#  ('герой', 30559),
#  ('ещё', 28284),
#  ('актёр', 27346),
#  ('время', 25200),
#  ('самый', 25121),
#  ('смотреть', 24680),
#  ('каждый', 22976),
#  ('роль', 22011),
#  ('картина', 21613),
#  ('первый', 21422),
#  ('сказать', 21421),
#  ('история', 20838),
#  ('кино', 20409),
#  ('сюжет', 20334),
#  ('большой', 19162),
#  ('игра', 18833),
#  ('мир', 17927),
#  ('год', 17694),
#  ('просмотр', 17225),
#  ('посмотреть', 16809),
#  ('главный', 16360),
#  ('стать', 16219),
#  ('говорить', 15513),
#  ('зритель', 15225),
#  ('друг', 15186),
#  ('любовь', 14896),
#  ('знать', 14809),
#  ('режиссёр', 14779),
#  ('персонаж', 14628),
#  ('видеть', 13953),
#  ('конец', 13857),
#  ('именно', 13853),
#  ('наш', 12925),
#  ('хотеть', 12856),
#  ('момент', 12470),
#  ('хотя', 12423),
#  ('сделать', 12314),
#  ('слово', 12066),
#  ('новый', 11677),
#  ('работа', 11629),
#  ('хотеться', 11443),
#  ('сцена', 11348),
#  ('лишь', 11244),
#  ('часть', 11057),
#  ('дело', 10931),
#  ('думать', 10922),
#  ('стоить', 10918),
#  ('понравиться', 10419),
#  ('начало', 10325),
#  ('место', 10230),
#  ('образ', 10207),
#  ('настоящий', 10192),
#  ('казаться', 10190),
#  ('вообще', 10056),
#  ('сыграть', 9971),
#  ('увидеть', 9743),
#  ('понять', 9715),
#  ('жить', 9482),
#  ('ребёнок', 9430),
#  ('музыка', 9383),
#  ('должный', 9363),
#  ('делать', 9299),
#  ('показать', 9266),
#  ('чувство', 9190),
#  ('интересный', 9153),
#  ('душа', 9088),
#  ('любить', 9067),
#  ('играть', 9000),
#  ('главное', 8814),
#  ('действительно', 8710),
#  ('актёрский', 8690),
#  ('нужно', 8538),
#  ('взгляд', 8516),
#  ('глаз', 8465),
#  ('понимать', 8144),
#  ('являться', 8076),
#  ('получиться', 8000),
#  ('идея', 7901),
#  ('последний', 7859),
#  ('чтоть', 7790),
#  ('экран', 7780),
#  ('смысл', 7765),
#  ('шедевр', 7753),
#  ('второй', 7692),
#  ('день', 7689),
#  ('иметь', 7448),
#  ('смочь', 7293),
#  ('происходить', 7266),
#  ('общий', 7252),
#  ('сторона', 7241),
#  ('идти', 7099),
#  ('плохой', 7056),
#  ('прекрасный', 6980),
#  ('мультфильм', 6900),
#  ('маленький', 6858),
#  ('её', 6841),
#  ('также', 6743),
#  ('настолько', 6716),
#  ('остаться', 6714),
#  ('книга', 6679),
#  ('минута', 6655),
#  ('холмс', 6647),
#  ('великолепный', 6586),
#  ('лицо', 6567),
#  ('сценарий', 6549),
#  ('любимый', 6539),
#  ('эмоция', 6529),
#  ('добрый', 6485),
#  ('дать', 6482),
#  ('поэтому', 6370),
#  ('больший', 6334),
#  ('красивый', 6325),
#  ('впечатление', 6313),
#  ('никто', 6239),
#  ('некоторый', 6233),
#  ('любой', 6232),
#  ('несколько', 6223),
#  ('сильный', 6199),
#  ('простой', 6144),
#  ('считать', 6092),
#  ('атмосфера', 6049),
#  ('отличный', 6043),
#  ('почему', 5997),
#  ('юмор', 5957),
#  ('вопрос', 5946),
#  ('совершенно', 5865),
#  ('жанр', 5857),
#  ('сразу', 5853),
#  ('мысль', 5839),
#  ('полный', 5832),
#  ('замечательный', 5824),
#  ('ждать', 5792),
#  ('пытаться', 5765),
#  ('становиться', 5747),
#  ('начинать', 5720),
#  ('заставлять', 5696),
#  ('сердце', 5655),
#  ('верить', 5654),
#  ('война', 5622),
#  ('кинематограф', 5605),
#  ('особенно', 5591),
#  ('снять', 5560),
#  ('голова', 5535),
#  ('немного', 5507),
#  ('событие', 5503),
#  ('сон', 5503),
#  ('итог', 5458),
#  ('найти', 5450),
#  ('сила', 5415),
#  ('данный', 5349),
#  ('получить', 5329),
#  ('остальной', 5276),
#  ('нолан', 5251),
#  ('слишком', 5135),
#  ('тема', 5127),
#  ('действие', 5110),
#  ('создать', 5109),
#  ('случай', 5104),
#  ('высокий', 5091),
#  ('внимание', 5029),
#  ('оказаться', 4983),
#  ('немой', 4969),
#  ('подобный', 4969),
#  ('многие', 4956),
#  ('давать', 4950),
#  ('великий', 4948),
#  ('огромный', 4934),
#  ('отец', 4927),
#  ('проблема', 4921),
#  ('возможно', 4913),
#  ('сказка', 4903),
#  ('девушка', 4889),
#  ('снимать', 4888),
#  ('однако', 4882),
#  ('никакой', 4862),
#  ('правда', 4827),
#  ('рука', 4813),
#  ('разный', 4805),
#  ('показывать', 4776),
#  ('спецэффект', 4772),
#  ('деньга', 4768),
#  ('абсолютно', 4744),
#  ('отношение', 4727),
#  ('гениальный', 4710),
#  ('единственный', 4705),
#  ('оставаться', 4695),
#  ('уровень', 4601),
#  ('час', 4582),
#  ('потрясать', 4579),
#  ('оскар', 4568),
#  ('вместе', 4564),
#  ('создатель', 4545),
#  ('отметить', 4534),
#  ('яркий', 4528),
#  ('довольно', 4517),
#  ('решить', 4508),
#  ('выйти', 4505),
#  ('кадр', 4499),
#  ('план', 4470),
#  ('оценка', 4451),
#  ('комедия', 4439),
#  ('судьба', 4426),
#  ('изз', 4406),
#  ('семья', 4382),
#  ('американский', 4318),
#  ('наверное', 4302),
#  ('вызывать', 4287),
#  ('мало', 4266),
#  ('несмотря', 4263),
#  ('смерть', 4249),
#  ('драма', 4203),
#  ('реальный', 4172),
#  ('шерлок', 4156),
#  ('выглядеть', 4139),
#  ('мнение', 4134),
#  ('далёкий', 4116),
#  ('смотреться', 4097),
#  ('лента', 4060),
#  ('многий', 4016),
#  ('дом', 4005),
#  ('человеческий', 3995),
#  ('желание', 3993),
#  ('назвать', 3993),
#  ('начать', 3987),
#  ('давно', 3954),
#  ('поставить', 3949),
#  ('слеза', 3891),
#  ('женщина', 3889),
#  ('имя', 3886),
#  ('обычный', 3882),
#  ('удаться', 3882),
#  ('город', 3876),
#  ('ради', 3863),
#  ('отлично', 3847),
#  ('вид', 3835),
#  ('ощущение', 3822),
#  ('современный', 3819),
#  ('молодой', 3803),
#  ('снятой', 3803),
#  ('парень', 3782),
#  ('менее', 3775),
#  ('шутка', 3769),
#  ('путь', 3759),
#  ('счастие', 3746),
#  ('нужный', 3718),
#  ('точно', 3717),
#  ('ожидать', 3693),
#  ('вроде', 3679),
#  ('способный', 3669),
#  ('похожий', 3667),
#  ('практически', 3662),
#  ('написать', 3653),
#  ('очередной', 3649),
#  ('реальность', 3639),
#  ('вещь', 3630),
#  ('диалог', 3620),
#  ('целое', 3617),
#  ('кроме', 3612),
#  ('спасибо', 3589),
#  ('взять', 3586),
#  ('невозможно', 3580),
#  ('вполне', 3575),
#  ('собственный', 3570),
#  ('достойный', 3530),
#  ('глубокий', 3500),
#  ('оно', 3473),
#  ('героиня', 3467),
#  ('снова', 3465),
#  ('оставить', 3460),
#  ('смешной', 3453),
#  ('пусть', 3435),
#  ('интересно', 3432),
#  ('ситуация', 3421),
#  ('сильно', 3418),
#  ('характер', 3412),
#  ('плюс', 3403),
#  ('лично', 3399),
#  ('нравиться', 3397),
#  ('полностью', 3393),
#  ('сколько', 3375),
#  ('тёмный', 3362),
#  ('весьма', 3352),
#  ('достаточно', 3350),
#  ('важный', 3348),
#  ('известный', 3343),
#  ('русский', 3310),
#  ('честно', 3300),
#  ('фраза', 3299),
#  ('качество', 3294),
#  ('столько', 3289),
#  ('сей', 3278),
#  ('пара', 3273),
#  ('финал', 3262),
#  ('писать', 3258),
#  ('надежда', 3251),
#  ('живой', 3242),
#  ('мечта', 3223),
#  ('протяжение', 3209),
#  ('близкий', 3208),
#  ('эпизод', 3202),
#  ('пока', 3174),
#  ('рецензия', 3170),
#  ('остров', 3164),
#  ('забыть', 3154),
#  ('пора', 3154),
#  ('детство', 3150),
#  ('многое', 3150),
#  ('благодаря', 3146),
#  ('жена', 3144),
#  ('состав', 3132),
#  ('заставить', 3130),
#  ('свет', 3126),
#  ('сын', 3125),
#  ('цель', 3123),
#  ('кстати', 3078),
#  ('равно', 3071),
#  ('линия', 3065),
#  ('пойти', 3053),
#  ('название', 3052),
#  ('произведение', 3050),
#  ('прекрасно', 3045),
#  ('талант', 3030),
#  ('помнить', 3025),
#  ('както', 3021),
#  ('узнать', 3021),
#  ('ктоть', 3015),
#  ('старый', 3009),
#  ('передать', 3007),
#  ('исполнение', 2999),
#  ('например', 2997),
#  ('далее', 2990),
#  ('собака', 2988),
#  ('справиться', 2963),
#  ('долго', 2956),
#  ('будущее', 2954),
#  ('мера', 2951),
#  ('страшный', 2948),
#  ('джон', 2943),
#  ('сложный', 2939),
#  ('безусловно', 2936),
#  ('скорее', 2933),
#  ('сценарист', 2923),
#  ('пожалуй', 2919),
#  ('брат', 2917),
#  ('представить', 2917),
#  ('джокер', 2899),
#  ('пример', 2897),
#  ('ричать', 2888),
#  ('готовый', 2872),
#  ('захватывать', 2868),
#  ('кристофер', 2865),
#  ('ставить', 2859),
#  ('читать', 2858),
#  ('количество', 2855),
#  ('чувствовать', 2852),
#  ('общество', 2848),
#  ('дух', 2843),
#  ('всякий', 2841),
#  ('оригинальный', 2840),
#  ('кинотеатр', 2835),
#  ('король', 2826),
#  ('показаться', 2818),
#  ('возможность', 2816),
#  ('страх', 2813),
#  ('концовка', 2811),
#  ('сюжетный', 2799),
#  ('положительный', 2791),
#  ('причём', 2790),
#  ('бог', 2784),
#  ('роберт', 2783),
#  ('удовольствие', 2769),
#  ('бывать', 2766),
#  ('всетаки', 2762),
#  ('творение', 2756),
#  ('либо', 2740),
#  ('обязательно', 2739),
#  ('отдельный', 2738),
#  ('саундтрек', 2711),
#  ('дружба', 2708),
#  ('задуматься', 2693),
#  ('ум', 2692),
#  ('заслуживать', 2681),
#  ('приятный', 2681),
#  ('автор', 2670),
#  ('фон', 2650),
#  ('джек', 2648),
#  ('лёгкий', 2647),
#  ('талантливый', 2640),
#  ('третий', 2627),
#  ('гай', 2620),
#  ('память', 2617),
#  ('песня', 2616),
#  ('сложно', 2616),
#  ('ужас', 2616),
#  ('бояться', 2609),
#  ('столь', 2603),
#  ('боевик', 2600),
#  ('отзыв', 2596),
#  ('век', 2594),
#  ('принцип', 2593),
#  ('пройти', 2589),
#  ('уметь', 2579),
#  ('свобода', 2561),
#  ('экранизация', 2551),
#  ('мальчик', 2546),
#  ('понятно', 2538),
#  ('работать', 2537),
#  ('чёрный', 2535),
#  ('умный', 2529),
#  ('какойтый', 2528),
#  ('детский', 2515),
#  ('красота', 2515),
#  ('взрослый', 2512),
#  ('страна', 2510),
#  ('успех', 2510),
#  ('триллер', 2500),
#  ('большинство', 2499),
#  ('заметить', 2482),
#  ('помочь', 2480),
#  ('актриса', 2475),
#  ('наблюдать', 2473),
#  ('ответ', 2472),
#  ('право', 2470),
#  ('находиться', 2467),
#  ('часто', 2466),
#  ('зло', 2464),
#  ('поступок', 2464),
#  ('ранний', 2458),
#  ('рыцарь', 2452),
#  ('серьёзный', 2442),
#  ('ибо', 2439),
#  ('факт', 2427),
#  ('сожаление', 2425),
#  ('далеко', 2422),
#  ('счастливый', 2420),
#  ('потерять', 2414),
#  ('порадовать', 2413),
#  ('мужчина', 2412),
#  ('некий', 2410),
#  ('появляться', 2400),
#  ('трогательный', 2400),
#  ('эффект', 2399),
#  ('изменить', 2382),
#  ('твой', 2382),
#  ('жаль', 2378),
#  ('мировой', 2376),
#  ('множество', 2372),
#  ('создавать', 2371),
#  ('ватсон', 2367),
#  ('значит', 2364),
#  ('пересматривать', 2361),
#  ('особый', 2360),
#  ('пародия', 2349),
#  ('вокруг', 2346),
#  ('бэтмена', 2333),
#  ('подумать', 2333),
#  ('иначе', 2330),
#  ('майкл', 2324),
#  ('прийтись', 2323),
#  ('необычный', 2320),
#  ('иной', 2316),
#  ('ваш', 2310),
#  ('оставлять', 2310),
#  ('рассказывать', 2309),
#  ('назад', 2305),
#  ('относиться', 2305),
#  ('минус', 2301),
#  ('порой', 2300),
#  ('выбор', 2288),
#  ('представлять', 2287),
#  ('картинка', 2280),
#  ('очередь', 2272),
#  ('деталь', 2271),
#  ('жестокий', 2266),
#  ('приключение', 2260),
#  ('оказываться', 2255),
#  ('сидеть', 2253),
#  ('надеяться', 2250),
#  ('вспомнить', 2240),
#  ('классика', 2239),
#  ('чистый', 2239),
#  ('причина', 2234),
#  ('идеальный', 2232),
#  ('лишний', 2231),
#  ('добро', 2226),
#  ('трудно', 2226),
#  ('съёмка', 2224),
#  ('никак', 2218),
#  ('речь', 2215),
#  ('насколько', 2210),
#  ('верный', 2208),
#  ('выше', 2206),
#  ('помощь', 2205),
#  ('море', 2203),
#  ('неплохой', 2199),
#  ('личность', 2198),
#  ('улыбка', 2197),
#  ('плохо', 2196),
#  ('стиль', 2195),
#  ('странный', 2181),
#  ('выходить', 2178),
#  ('ход', 2178),
#  ('прийти', 2174),
#  ('ps', 2167),
#  ('милый', 2161),
#  ('мозг', 2153),
#  ('доктор', 2150),
#  ('приятно', 2142),
#  ('присутствовать', 2141),
#  ('великолепно', 2127),
#  ('продолжение', 2126),
#  ('точка', 2126),
#  ('родитель', 2121),
#  ('среди', 2121),
#  ('музыкальный', 2119),
#  ('половина', 2113),
#  ('помогать', 2102),
#  ('машина', 2100),
#  ('российский', 2098),
#  ('смеяться', 2097),
#  ('существовать', 2095),
#  ('подобрать', 2092),
#  ('особо', 2087),
#  ('тяжёлый', 2085),
#  ('вовсе', 2078),
#  ('явно', 2077),
#  ('мать', 2076),
#  ('слышать', 2074),
#  ('называть', 2064),
#  ('знакомый', 2055),
#  ('появиться', 2055),
#  ('злодей', 2051),
#  ('искать', 2050),
#  ('поверить', 2050),
#  ('касаться', 2048),
#  ('целый', 2045),
#  ('искусство', 2043),
#  ('восторг', 2042),
#  ('невероятный', 2039),
#  ('постоянно', 2037),
#  ('ужасный', 2036),
#  ('начинаться', 2028),
#  ('вызвать', 2018),
#  ('выход', 2017),
#  ('советовать', 2016),
#  ('мультик', 2014),
#  ('невероятно', 2013),
#  ('радовать', 2009),
#  ('хватать', 2006),
#  ('настроение', 2005),
#  ('мастер', 2003),
#  ('народ', 2002),
#  ('оба', 2002),
#  ('нечто', 1993),
#  ('напоминать', 1991),
#  ('прошлое', 1984),
#  ('качественный', 1983),
#  ('важно', 1982),
#  ('плакать', 1976),
#  ('роман', 1970),
#  ('глупый', 1965),
#  ('земля', 1961),
#  ('получать', 1961),
#  ('словно', 1961),
#  ('радость', 1953),
#  ('попасть', 1951),
#  ('разум', 1947),
#  ('миллион', 1940),
#  ('чудо', 1939),
#  ('стараться', 1934),
#  ('легко', 1930),
#  ('получаться', 1926),
#  ('вечный', 1924),
#  ('удивительный', 1923),
#  ('интерес', 1918),
#  ('боль', 1912),
#  ('долгий', 1910),
#  ('уйти', 1909),
#  ('запоминаться', 1903),
#  ('держать', 1902),
#  ('убить', 1902),
#  ('пират', 1901),
#  ('криминальный', 1900),
#  ('сначала', 1897),
#  ('голос', 1894),
#  ('финальный', 1894),
#  ('спасти', 1890),
#  ('переживать', 1888),
#  ('глубина', 1886),
#  ('дикаприо', 1883),
#  ('светлый', 1882),
#  ('возраст', 1874),
#  ('режиссура', 1869),
#  ('секунда', 1869),
#  ('вернуться', 1864),
#  ('буквально', 1858),
#  ('сомнение', 1855),
#  ('жизненный', 1853),
#  ('собственно', 1852),
#  ('девочка', 1850),
#  ('советский', 1849),
#  ('составлять', 1849),
#  ('скорсез', 1846),
#  ('следовать', 1846),
#  ('декорация', 1844),
#  ('хит', 1843),
#  ('против', 1840),
#  ('находить', 1834),
#  ('гений', 1828),
#  ('клуб', 1819),
#  ('наоборот', 1814),
#  ('понастоящий', 1803),
#  ('попытка', 1800),
#  ('истинный', 1799),
#  ('проект', 1799),
#  ('вера', 1797),
#  ('приходить', 1796),
#  ('борьба', 1793),
#  ('брать', 1785),
#  ('балл', 1777),
#  ('возникать', 1774),
#  ('порядок', 1774),
#  ('развитие', 1774),
#  ('забывать', 1769),
#  ('ценность', 1765),
#  ('гораздо', 1763),
#  ('искренний', 1759),
#  ('иствуд', 1759),
#  ('черта', 1757),
#  ('список', 1745),
#  ('исключение', 1741),
#  ('поразить', 1739),
#  ('произойти', 1728),
#  ('режиссёрский', 1728),
#  ('гдеть', 1724),
#  ('любитель', 1719),
#  ('забавный', 1717),
#  ('приходиться', 1717),
#  ('зря', 1714),
#  ('браво', 1713),
#  ('суть', 1704),
#  ('ожидание', 1703),
#  ('бороться', 1701),
#  ('правило', 1699),
#  ('придумать', 1699),
#  ('исполнить', 1696),
#  ('уверенный', 1693),
#  ('ошибка', 1692),
#  ('повествование', 1685),
#  ('звучать', 1681),
#  ('естественно', 1672),
#  ('детектив', 1671),
#  ('вести', 1664),
#  ('белый', 1660),
#  ('слава', 1657),
#  ('бюджет', 1655),
#  ('видно', 1653),
#  ('счёт', 1653),
#  ('впервые', 1652),
#  ('кровь', 1647),
#  ('род', 1647),
#  ('небо', 1646),
#  ('напряжение', 1645),
#  ('повод', 1644),
#  ('дорога', 1641),
#  ('таковой', 1640),
#  ('трилогия', 1638),
#  ('матрица', 1634),
#  ('рассказать', 1632),
#  ('следующий', 1631),
#  ('красиво', 1625),
#  ('обычно', 1618),
#  ('одновременно', 1617),
#  ('рядом', 1617),
#  ('суметь', 1616),
#  ('таки', 1613),
#  ('определённый', 1612),
#  ('отсутствие', 1611),
#  ('ходить', 1610),
#  ('итак', 1606),
#  ('сравнение', 1606),
#  ('убийство', 1606),
#  ('ничто', 1604),
#  ('пересмотреть', 1603),
#  ('небольшой', 1602),
#  ('видимо', 1601),
#  ('равнодушный', 1600),
#  ('воспоминание', 1598),
#  ('титр', 1597),
#  ('убивать', 1596),
#  ('вновь', 1595),
#  ('зато', 1595),
#  ('скучный', 1595),
#  ('идеально', 1594),
#  ('прежде', 1594),
#  ('вывод', 1588),
#  ('согласиться', 1588),
#  ('сознание', 1586),
#  ('костюм', 1583),
#  ('звезда', 1580),
#  ('дочь', 1576),
#  ('игрушка', 1575),
#  ('шикарный', 1573),
#  ('мечтать', 1572),
#  ('весёлый', 1571),
#  ('тюрьма', 1571),
#  ('внутренний', 1569),
#  ('использовать', 1569),
#  ('удивить', 1569),
#  ('внутри', 1561),
#  ('высота', 1559),
#  ('голливуд', 1556),
#  ('пол', 1554),
#  ('запомниться', 1553),
#  ('чемтый', 1552),
#  ('предыдущий', 1550),
#  ('число', 1548),
#  ('вряд', 1540),
#  ('команда', 1539),
#  ('добавить', 1534),
#  ('отличаться', 1534),
#  ('хозяин', 1533),
#  ('дракон', 1532),
#  ('леджер', 1532),
#  ('раскрыть', 1529),
#  ('сегодня', 1529),
#  ('намного', 1525),
#  ('умереть', 1525),
#  ('принять', 1524),
#  ('награда', 1523),
#  ('отрицательный', 1523),
#  ('продолжать', 1523),
#  ('личный', 1520),
#  ('навсегда', 1515),
#  ('америка', 1514),
#  ('уважение', 1513),
#  ('чеготь', 1511),
#  ('желать', 1508),
#  ('зал', 1506),
#  ('хатико', 1506),
#  ('кольцо', 1505),
#  ('задача', 1500),
#  ('поражать', 1500),
#  ('искренне', 1497),
#  ('голливудский', 1495),
#  ('недостаток', 1494),
#  ('операторский', 1494),
#  ('создание', 1491),
#  ('удачный', 1491),
#  ('компания', 1490),
#  ('закончиться', 1489),
#  ('участие', 1489),
#  ('достоинство', 1483),
#  ('оценить', 1480),
#  ('природа', 1479),
#  ('странно', 1479),
#  ('драка', 1472),
#  ('знаменитый', 1471),
#  ('заслужить', 1470),
#  ('тонкий', 1470),
#  ('улица', 1470),
#  ('мелочь', 1467),
#  ('воля', 1461),
#  ('подходить', 1461),
#  ('элемент', 1461),
#  ('результат', 1456),
#  ('бой', 1453),
#  ('всётаки', 1451),
#  ('уилла', 1447),
#  ('чей', 1447),
#  ('случиться', 1443),
#  ('состояние', 1443),
#  ('группа', 1442),
#  ('решение', 1442),
#  ('смешно', 1442),
#  ('испытывать', 1439),
#  ('решать', 1439),
#  ('правильный', 1437),
#  ('больной', 1436),
#  ('нога', 1431),
#  ('смех', 1431),
#  ('отличие', 1429),
#  ('правильно', 1428),
#  ('фантастический', 1426),
#  ('родный', 1424),
#  ('прочитать', 1423),
#  ('однажды', 1422),
#  ('окружающий', 1422),
#  ('постановка', 1421),
#  ('понятный', 1417),
#  ('сопровождение', 1416),
#  ('нечего', 1415),
#  ('неплохо', 1413),
#  ('ряд', 1413),
#  ('язык', 1413),
#  ('описать', 1404),
#  ('судить', 1403),
#  ('погоня', 1401),
#  ('выбрать', 1400),
#  ('признаться', 1400),
#  ('цвет', 1400),
#  ('тип', 1399),
#  ('неожиданный', 1398),
#  ('основный', 1398),
#  ('переживание', 1398),
#  ('открыть', 1397),
#  ('позволять', 1396),
#  ('учить', 1395),
#  ('классический', 1394),
#  ('волшебный', 1393),
#  ('поклонник', 1392),
#  ('вместо', 1388),
#  ('мрачный', 1386),
#  ('мартин', 1385),
#  ('закон', 1383),
#  ('оператор', 1381),
#  ('удивительно', 1376),
#  ('тупой', 1375),
#  ('куча', 1374),
#  ('малый', 1369),
#  ('уникальный', 1365),
#  ('нормальный', 1364),
#  ('обладать', 1364),
#  ('меняться', 1363),
#  ('жестокость', 1358),
#  ('разговор', 1358),
#  ('нести', 1357),
#  ('зрение', 1354),
#  ('сравнивать', 1353),
#  ('душевный', 1352),
#  ('злой', 1352),
#  ('потратить', 1349),
#  ('блокбастер', 1345),
#  ('звук', 1339),
#  ('терять', 1337),
#  ('вопервое', 1336),
#  ('слабый', 1336),
#  ('появление', 1333),
#  ('зелёный', 1332),
#  ('вкус', 1330),
#  ('фантастика', 1329),
#  ('крайне', 1325),
#  ('несомненно', 1325),
#  ('поколение', 1325),
#  ('безумно', 1322),
#  ('помоему', 1322),
#  ('пёс', 1321),
#  ('эмоциональный', 1320),
#  ('творчество', 1317),
#  ('завораживать', 1316),
#  ('задумываться', 1316),
#  ('отдельно', 1316),
#  ('проходить', 1316),
#  ('какиеть', 1313),
#  ('степень', 1309),
#  ('масса', 1307),
#  ('подарить', 1306),
#  ('похвала', 1306),
#  ('блестящий', 1305),
#  ('тарантино', 1305),
#  ('рекомендовать', 1304),
#  ('стремиться', 1303),
#  ('бесподобный', 1298),
#  ('камера', 1296),
#  ('банальный', 1295),
#  ('ясно', 1295),
#  ('дыхание', 1293),
#  ('фантазия', 1293),
#  ('оригинал', 1291),
#  ('основа', 1291),
#  ('редко', 1291),
#  ('вспоминать', 1290),
#  ('враг', 1288),
#  ('доброта', 1288),
#  ('доказать', 1286),
#  ('понимание', 1282),
#  ('планета', 1278),
#  ('жертва', 1277),
#  ('попадать', 1277),
#  ('убийца', 1276),
#  ('система', 1275),
#  ('спустя', 1275),
#  ('принимать', 1273),
#  ('престиж', 1268),
#  ('английский', 1266),
#  ('композитор', 1265),
#  ('россия', 1264),
#  ('эдвард', 1264),
#  ('мистер', 1262),
#  ('коготь', 1261),
#  ('психологический', 1260),
#  ('бред', 1252),
#  ('середина', 1251),
#  ('власть', 1246),
#  ('впечатлить', 1246),
#  ('культовый', 1246),
#  ('замечать', 1244),
#  ('бежать', 1243),
#  ('крайний', 1242),
#  ('прочий', 1241),
#  ('слушать', 1241),
#  ('поведение', 1239),
#  ('карьера', 1237),
#  ('компьютерный', 1237),
#  ('собрать', 1236),
#  ('истина', 1235),
#  ('стоять', 1235),
#  ('точнее', 1235),
#  ('деппа', 1233),
#  ('шаг', 1232),
#  ('леонардо', 1231),
#  ('почемуть', 1230),
#  ('мастерство', 1229),
#  ('богатый', 1228),
#  ('семь', 1227),
#  ('начаться', 1224),
#  ('неповторимый', 1224),
#  ('корабль', 1223),
#  ('мораль', 1223),
#  ('трейлер', 1223),
#  ('чужой', 1220),
#  ('различный', 1218),
#  ('крис', 1215),
#  ('робот', 1215),
#  ('восхищаться', 1214),
#  ('проклятый', 1210),
#  ('отдать', 1209),
#  ('дауни', 1208),
#  ('визуальный', 1207),
#  ('воспринимать', 1207),
#  ('отечественный', 1207),
#  ('прожить', 1207),
#  ('шанс', 1207),
#  ('простить', 1202),
#  ('провести', 1200),
#  ('наивный', 1198),
#  ('лоу', 1197),
#  ('страшно', 1197),
#  ('особенный', 1194),
#  ('прямо', 1194),
#  ('способ', 1193),
#  ('наверно', 1191),
#  ('сниматься', 1190),
#  ('грустный', 1187),
#  ('поиск', 1184),
#  ('хватить', 1182),
#  ('грань', 1181),
#  ('стена', 1181),
#  ('золотой', 1179),
#  ('непонятный', 1177),
#  ('животное', 1174),
#  ('джеймс', 1173),
#  ('бойцовский', 1169),
#  ('джим', 1169),
#  ('тело', 1169),
#  ('рассказ', 1168),
#  ('драматический', 1165),
#  ('кевин', 1165),
#  ('сумасшедший', 1165),
#  ('исторический', 1164),
#  ('почувствовать', 1164),
#  ('чудесный', 1164),
#  ('однозначно', 1162),
#  ('менять', 1160),
#  ('американец', 1159),
#  ('затем', 1159),
#  ('существование', 1158),
#  ('сходить', 1157),
#  ('стивен', 1155),
#  ('ценить', 1154),
#  ('наполнить', 1153),
#  ('ди', 1151),
#  ('быстро', 1150),
#  ('семейный', 1150),
#  ('трагедия', 1147),
#  ('потрясающе', 1146),
#  ('увы', 1146),
#  ('встреча', 1144),
#  ('измениться', 1143),
#  ('джонни', 1141),
#  ('пачиный', 1141),
#  ('разочаровать', 1141),
#  ('способность', 1141),
#  ('чарли', 1141),
#  ('клинт', 1137),
#  ('выделить', 1135),
#  ('крупный', 1135),
#  ...]
