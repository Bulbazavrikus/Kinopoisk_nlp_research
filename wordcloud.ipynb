# %%
import pandas as pd

# %%
df = pd.read_csv('data/lemmed_df.csv', usecols=['content', 'grade3', 'grade10', 'clean_content', 'movie_name', 'review_id'])
df.head()
# Out:
#                                              content   grade3  grade10  \
# 0  блеф одна из моих самых любимых комедий этот ф...     Good     10.0
# 1  адриано челентано продолжает радовать нас свои...     Good      0.0
# 2  несомненно это один из великих фильмов 80х год...     Good     10.0
# 3  эта фраза на мой взгляд отражает сюжет несомне...     Good      0.0
# 4  как пела земфира скорее всего по совершенно др...  Neutral      7.0
#
#                                        clean_content   movie_name  review_id
# 0  блеф самый любимый комедия фильм наверно смотр...  Блеф (1976)      17144
# 1  адриано челентано продолжать радовать свой раб...  Блеф (1976)      17139
# 2  несомненно это великий фильм 80х год исключите...  Блеф (1976)      17137
# 3  фраза взгляд отражать сюжет несомненно прекрас...  Блеф (1976)      17135
# 4  петь земфира скорее весь совершенно повод ещё ...  Блеф (1976)      17151

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pymorphy3

def generate_wordcloud(movie_name, dataframe):
    # Фильтруем рецензии для указанного фильма
    reviews = dataframe[dataframe['movie_name'] == movie_name]['clean_content']


    
    # Нормализация названия фильма для дальнейшего удаления (опционально)
    morph_analyzer = pymorphy3.MorphAnalyzer()


    movie_name = movie_name.rpartition(' ')[0]

    movie_name = movie_name.lower()

    morph_analyzer.parse(movie_name)[0].normal_form
    

    
    # Объединяем все рецензии в один текст
    text = " ".join(reviews).replace('фильм', '').replace('это', '').replace('который', '').replace('весь', '').replace('всё', '')
    # Создаем облако слов
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    
    # Визуализация
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(f"Word Cloud for '{movie_name}'", fontsize=16)
    plt.show()

# Вызов функции
generate_wordcloud("Остров сокровищ (1988)", df)

# %%
df['movie_name'].unique()
# Out:
# array(['Блеф (1976)', 'Малыш (1921)',
#        'Шерлок Холмс и доктор Ватсон Охота на тигра (1980)',
#        'Рапунцель Запутанная история (2010)',
#        'Как приручить дракона (2010)', 'Корпорация монстров (2001)',
#        'Шестое чувство (1999)', 'Пока не сыграл в ящик (2007)',
#        'ВАЛЛ·И (2008)', 'Апокалипсис (2006)', 'Назад в будущее (1985)',
#        'Самый быстрый «Индиан» (2005)', 'Достучаться до небес (1997)',
#        'Казино (1995)', 'В диких условиях (2007)', 'Отец солдата (1964)',
#        'Непрощенный (1992)', 'Золотая лихорадка (1925)',
#        'Храброе сердце (1995)', 'Одиннадцать друзей Оушена (2001)',
#        'Один дома (1990)', 'Красавица и чудовище (1991)',
#        'Шерлок Холмс Игра теней (2011)', 'Проверка на дорогах (1971)',
#        'Судьба человека (1959)', 'Жизнь в розовом цвете (2007)',
#        'Мотылек (1973)', 'Подмена (2008)', 'Лис и пес (1981)',
#        'Шерлок Холмс (2009)', 'Семь самураев (1954)',
# ...

# %%
generate_wordcloud("Леон (1994)", df)

# %%
generate_wordcloud("ВАЛЛ·И (2008)", df)
